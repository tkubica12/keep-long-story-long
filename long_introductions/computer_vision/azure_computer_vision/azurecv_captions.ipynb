# %% [markdown]
# # Get captions, dense captions and tags from Azure Computer Vision

# %%
# !pip install azure-ai-vision --user

# %%
# imports
import requests
import os
from dotenv import load_dotenv
import pandas as pd
import azure.ai.vision as sdk
import time

# %%
# Load envs
load_dotenv('.env')

# Azure Computer Vision
key = os.getenv("azure_cv_key")
endpoint = os.getenv("azure_cv_endpoint")

# Images to process
image_dir = './val2017/'

# Get Azure Computer Vision client
service_options = sdk.VisionServiceOptions(endpoint, key)

# %%
def analyze_image(imagefile):
    """
    Analyze an image using Azure Computer Vision API
    Implement retry logic due to rate limits (denseCaptions in preview offered just 20 requests per minute)
    """
    query = "?api-version=2023-02-01-preview&features=caption,denseCaptions"
    url = endpoint + "/computervision/imageanalysis:analyze" + query
    headers = {
        "Content-type": "application/octet-stream",
        "Ocp-Apim-Subscription-Key": key,
    }

    # Read the image file
    with open(imagefile, "rb") as f:
        data = f.read()

    # Sending the requests
    for retries in range(10):
        r = requests.post(url, data=data, headers=headers)
        if r.status_code == 200:
            results = r.json()
            break
        else:
            print(f"Error: {r.status_code}, will retry")
            time.sleep(61)
    else:
        raise Exception("Maximum number of retries reached")    
    
    return results

# %%
df = pd.DataFrame()
num_files = len(os.listdir(image_dir))

# Iterate over images
for i, filename in enumerate(os.listdir(image_dir)):
    print(f"{i} out of {num_files} - {filename}")
    result = analyze_image(image_dir + filename)

    print(result)
        
    # Parse results
    caption = result["captionResult"]["text"]
    object_captions = ", ".join(set(object["text"] for object in result["denseCaptionsResult"]["values"]))
    all_captions = f"{caption}, {object_captions}"

    # Store results
    result = { "filename": filename, "caption": caption, "all_captions": all_captions }
    row = pd.DataFrame(result, index=[0])
    df = pd.concat([df, row], axis=0)
    print(f"---> {caption}")

# %%
df.sample(20)
# Out:
#            filename                                            caption  \
# 0  000000187585.jpg                a man doing a trick on a skateboard
# 0  000000293324.jpg          a group of airplanes parked at an airport
# 0  000000454661.jpg               cars on a street with traffic lights
# 0  000000087742.jpg                 a vase with peacock feathers in it
# 0  000000360943.jpg                    a cat sitting on a window ledge
# 0  000000566923.jpg  a man with blood on his face holding a fire hy...
# 0  000000044068.jpg                    a teddy bear sitting on a chair
# 0  000000532855.jpg                      a person is skating on a rail
# 0  000000577539.jpg   a bowl of ice cream with marshmallows and banana
# 0  000000453860.jpg                            a pair of black luggage
# 0  000000212559.jpg                                    sheep in a barn
# 0  000000546826.jpg                    a red scissors next to a marker
# 0  000000196141.jpg                   a baseball player swinging a bat
# 0  000000256407.jpg        a clock with cups and saucers on a red wall
# 0  000000304291.jpg                            a horse walking on dirt
# 0  000000237928.jpg      a kitchen with white cabinets and a microwave
# 0  000000564023.jpg                    a public bathroom with a toilet
# 0  000000061747.jpg                      a woman on skis on a mountain
# 0  000000036936.jpg                a man and woman playing video games
# 0  000000360137.jpg  a person holding an umbrella looking out over ...
#
#                                         all_captions
# 0  a man doing a trick on a skateboard, a man sit...
# 0  a group of airplanes parked at an airport, a g...
# 0  cars on a street with traffic lights, a white ...
# 0  a vase with peacock feathers in it, a window w...
# 0  a cat sitting on a window ledge, a cat sitting...
# 0  a man with blood on his face holding a fire hy...
# 0  a teddy bear sitting on a chair, a teddy bear ...
# 0  a person is skating on a rail, a person is ska...
# 0  a bowl of ice cream with marshmallows and bana...
# 0  a pair of black luggage, a black suitcase with...
# 0  sheep in a barn, a close-up of a sheep, a shee...
# 0  a red scissors next to a marker, a red scissor...
# 0  a baseball player swinging a bat, a baseball p...
# 0  a clock with cups and saucers on a red wall, a...
# 0  a horse walking on dirt, a horse standing on t...
# 0  a kitchen with white cabinets and a microwave,...
# 0  a public bathroom with a toilet, a public bath...
# 0  a woman on skis on a mountain, a woman on skis...
# 0  a man and woman playing video games, a candle ...
# 0  a person holding an umbrella looking out over ...

# %%
# Save results
df.to_parquet("azurecv_image_captions.parquet")
